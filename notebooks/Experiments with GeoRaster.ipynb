# %%
# %matplotlib inline
from telluric.georaster import GeoRaster2

# %%
raster = GeoRaster2.open('../tests/data/raster/rgb.tif', ['red', 'green', 'blue'])
raster.num_bands, raster.width, raster.height
# Out:
# (3, 100, 100)

# %%
raster

# %%
raster.image.mask[:, :10, :10] = True
print(raster.num_pixels(), raster.num_pixels_data(), raster.num_pixels_nodata())
raster
# Out:
# 10000 9900 100

# %%
raster.mean(), raster.max(), raster.std()
# Out:
# ([85.133838383838381, 103.35151515151514, 75.570404040404043],
#  [253, 253, 253],
#  [37.211529743788688, 23.508628820444784, 25.343398973971958])

# %%
raster.histogram()

# %%
raster.limit_to_bands(['red'])

# %%
for resized in [raster.resize(ratio=.5), 
                raster.resize(ratio_x=.5, ratio_y=0.25),
                raster.resize(dest_width=30)]:
    print(resized.width, resized.height)
# Out:
# 50 50
# 50 25
# 30 30

# %%
raster.center()

# %%
raster.bounds()

# %%
raster.footprint()

# %%
raster.corners()
# Out:
# {'bl': <telluric.vectors.GeoVector at 0x7f93a6aa2710>,
#  'br': <telluric.vectors.GeoVector at 0x7f93a6aa2278>,
#  'ul': <telluric.vectors.GeoVector at 0x7f93a7cc2f60>,
#  'ur': <telluric.vectors.GeoVector at 0x7f93a6aa2940>}

# %%
raster.area()
# Out:
# 39838563.8657105
